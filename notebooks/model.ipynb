# %%
import re
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

# %%
df = pd.read_csv('../data/recipes.csv')

# %%
df.shape
# Out:
# (767, 6)

# %%
df.head()
# Out:
#                                                image  \
# 0  https://pinchofyum.com/wp-content/uploads/Ital...
# 1  https://pinchofyum.com/wp-content/uploads/Cris...
# 2  https://pinchofyum.com/wp-content/uploads/Goch...
# 3  https://pinchofyum.com/wp-content/uploads/Air-...
# 4  https://pinchofyum.com/wp-content/uploads/Two-...
#
#                                         title  \
# 0                     Big Yummy Italian Salad
# 1  Crispy Rice Salad with Cucumbers and Herbs
# 2                  Incredible Gochujang Sauce
# 3          Ridiculously Good Air Fryer Salmon
# 4             Two Huge Chocolate Chip Cookies
#
#                                          description  total time  \
# 0  I love a big Italian salad! Crisp romaine, sal...  15 minutes
# 1  Paper-thin veggies, a shower of herbs, a pile ...  30 minutes
# 2  This delightful, creamy, silky, incredible goc...   5 minutes
# 3  This air fryer salmon is TOO GOOD. Crisped and...  13 minutes
# 4  Just two chocolate chip cookies – lightly cris...  15 minutes
#
#                                          ingredients  \
# 0  chees like provolon romain lettuc splash peppe...
# 1  cornstarch english cucumb peanut brown sugar l...
# 2  gochujang sauc clove garlic soy sauc rice vine...
# 3  paprika cornstarch onion powder brown sugar ga...
# 4  allpurpos flour cornstarch chocol chip bake so...
#
#                                         instructions
# 0  ['Prep Salad Stuff: Chop all your salad veggie...
# 1  ['Dressing: Blitz everything up in a blender o...
# 2  ['Mix all ingredients together in a small bowl...
# 3  ['Prep the salmon: Remove the skin from your s...
# 4  ['Preheat the oven to 350 degrees.', 'Mix butt...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   image         767 non-null    object
#  1   title         767 non-null    object
#  2   description   766 non-null    object
#  3   total time    767 non-null    object
#  4   ingredients   767 non-null    object
#  5   instructions  767 non-null    object
# dtypes: object(6)
# memory usage: 36.1+ KB

# %%
def norm(s):
    s = "" if pd.isna(s) else str(s).lower()
    s = re.sub(r"[^a-z0-9, /+-]", " ", s).replace("/", " ")
    return " ".join([t for t in re.split(r"[,\s]+", s) if t])

# %%
df["ing_norm"] = df["ingredients"].astype(str).apply(norm)

# %%
vec = TfidfVectorizer(ngram_range=(1, 2), min_df=2)
X = vec.fit_transform(df["ing_norm"])

# %%
knn = NearestNeighbors(metric="cosine", algorithm="brute")
knn.fit(X)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
def find_recipes_knn(ingredients, k=10, require_all=False):
    q = norm(ingredients)
    q_vec = vec.transform([q])
    dists, idxs = knn.kneighbors(q_vec, n_neighbors=min(k*5, X.shape[0]))
    out = df.iloc[idxs[0]].copy()
    out["score"] = 1 - dists[0]

    if require_all:
        toks = set(q.split())
        out = out[out["ing_norm"].apply(lambda s: toks.issubset(set(s.split())))]

    cols = [c for c in ["title", "total_time", "ingredients", "instructions", "image", "score"] if c in out.columns]
    return out[cols].head(k)

# %%
find_recipes_knn("tomato, onion, garlic", k=10, require_all=True)
# Out:
#                                                title  \
# 267                          Three Cheese Baked Ziti
# 365           Freezer Meal Moroccan-Spiced Chickpeas
# 462  Creamy Tomato Risotto with Pan Fried Barramundi
# 343               No-Boil Baked Penne with Meatballs
# 292                                 Greek Baked Orzo
# 17                          5 Ingredient Tomato Soup
# 720           Slow Cooker Creole Chicken and Sausage
# 80                       Simple Homemade Tomato Soup
# 344           Instant Pot Creole Chicken and Sausage
# 269                                 Vegetarian Chili
#
#                                            ingredients  \
# 267  crush tomato mascarpon chees tomato sauc ziti ...
# 365  chickpea chili powder cumin turmer garam masal...
# 462  lemon juic parmesan chees arborio rice clove m...
# 343  crush fire roast tomato onion powder land lake...
# 292  dri oregano butter dice fireroast tomato veget...
# 17   san marzano tomato clove smash garlic yellow o...
# 720  dice tomato green bell pepper tomato sauc brow...
# 80   cream flour yellow onion dri thyme bay leaf ch...
# 344  boneless skinless chicken breast green red bel...
# 269  bean choic fresh mushroom dice green chile cum...
#
#                                           instructions  \
# 267  ['Sauce: Heat olive oil in a large pot over me...
# 365                                                 []
# 462  ['Heat the chicken broth in a saucepan and kee...
# 343  ['Preheat oven to 400 degrees.', 'Mix all of t...
# 292  ['Preheat the oven to 400 degrees.', 'In a lar...
# 17   ['Make the Tomato Soup: Put the tomatoes, butt...
# 720  ['Place the essential ingredients in the crock...
# 80   ['Fry the bacon in a large soup pot over mediu...
# 344  ['Prep all your ingredients.', 'Cook everythin...
# 269  ['Make the “meat” – pulse all ingredients in a...
#
#                                                  image     score
# 267  https://pinchofyum.com/wp-content/uploads/Thre...  0.232067
# 365  https://pinchofyum.com/wp-content/uploads/Moro...  0.214486
# 462  https://pinchofyum.com/wp-content/uploads/Barr...  0.212351
# 343  https://pinchofyum.com/wp-content/uploads/Bake...  0.194682
# 292  https://pinchofyum.com/wp-content/uploads/Gree...  0.185875
# 17   https://pinchofyum.com/wp-content/uploads/Toma...  0.097926
# 720  https://pinchofyum.com/wp-content/uploads/Creo...  0.095442
# 80   https://pinchofyum.com/wp-content/uploads/Home...  0.090247
# 344  https://pinchofyum.com/wp-content/uploads/Chic...  0.085194
# 269  https://pinchofyum.com/wp-content/uploads/Vege...  0.085014
